# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/wineq.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
df.describe().iloc[1:,:12]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# mean       8.311111          0.531339     0.268364        2.532152   0.086933
# std        1.747595          0.179633     0.196686        1.355917   0.047267
# min        4.600000          0.120000     0.000000        0.900000   0.012000
# 25%        7.100000          0.392500     0.090000        1.900000   0.070000
# 50%        7.900000          0.520000     0.250000        2.200000   0.079000
# 75%        9.100000          0.640000     0.420000        2.600000   0.090000
# max       15.900000          1.580000     1.000000       15.500000   0.611000
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# mean            15.615486             45.914698  0.996730  3.311015
# std             10.250486             32.782130  0.001925  0.156664
# min              1.000000              6.000000  0.990070  2.740000
# 25%              7.000000             21.000000  0.995570  3.205000
# 50%             13.000000             37.000000  0.996680  3.310000
# 75%             21.000000             61.000000  0.997845  3.400000
# max             68.000000            289.000000  1.003690  4.010000
#
#       sulphates    alcohol   quality
# mean   0.657708  10.442111  5.657043
# std    0.170399   1.082196  0.805824
# min    0.330000   8.400000  3.000000
# 25%    0.550000   9.500000  5.000000
# 50%    0.620000  10.200000  6.000000
# 75%    0.730000  11.100000  6.000000
# max    2.000000  14.900000  8.000000

# %%
# great, no null values!
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
# we will train out model on this 6 output classes.
# And try to implement OOD detection.
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
# dataset is imbalanced
df['quality'].value_counts()
# Out:
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: quality, dtype: int64

# %% [markdown]
# ### Performing Oversampling using SMOTE

# %%
import pathlib
curr_dir = pathlib.Path()
home_dir = curr_dir.parent.parent.parent


data = pd.read_csv('E:/MLOps/WineQ/wineq/data/raw/wineq.csv')
df = data.copy()

# %%
# dataset is imbalanced, need to do oversampling
df['quality'].value_counts()
# Out:
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: quality, dtype: int64

# %%
# lets use SMOTE for oversampling
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state = 42)
X = df.drop(columns = ['quality'])
y = df['quality']

X_res, y_res = smote.fit_resample(X, y)

# %%
print('Before Sampling')
print('X: ', X.shape)
print('y: ', y.shape)

print('\nAfter Sampling')
print('X_res: ', X_res.shape)
print('y_res: ', y_res.shape)
# Out:
# Before Sampling
# X:  (1143, 12)
# y:  (1143,)
#
# After Sampling
# X_res:  (2898, 12)
# y_res:  (2898,)

# %%
display(y.value_counts())
display(y_res.value_counts())
# Out:
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: quality, dtype: int64
# 5    483
# 6    483
# 7    483
# 4    483
# 8    483
# 3    483
# Name: quality, dtype: int64

# %%
smote.get_params()
# Out:
# {'k_neighbors': 5,
#  'n_jobs': None,
#  'random_state': 42,
#  'sampling_strategy': 'auto'}

# %%
smote.get_feature_names_out()
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'Id'], dtype=object)

# %%
pd.options.display.float_format = '{:.2f}'.format
print('Before Oversampling')
print('Shape X: ', X.shape)
display(X.describe().iloc[1:, :-1])
print('-' * 140)
print('After Oversampling')
print('Shape X_Res: ', X_res.shape)
display(X_res.describe().iloc[1:, :-1])
# Out:
# Before Oversampling
# Shape X:  (1143, 12)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# mean           8.31              0.53         0.27            2.53       0.09
# std            1.75              0.18         0.20            1.36       0.05
# min            4.60              0.12         0.00            0.90       0.01
# 25%            7.10              0.39         0.09            1.90       0.07
# 50%            7.90              0.52         0.25            2.20       0.08
# 75%            9.10              0.64         0.42            2.60       0.09
# max           15.90              1.58         1.00           15.50       0.61
#
#       free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# mean                15.62                 45.91     1.00 3.31       0.66
# std                 10.25                 32.78     0.00 0.16       0.17
# min                  1.00                  6.00     0.99 2.74       0.33
# 25%                  7.00                 21.00     1.00 3.21       0.55
# 50%                 13.00                 37.00     1.00 3.31       0.62
# 75%                 21.00                 61.00     1.00 3.40       0.73
# max                 68.00                289.00     1.00 4.01       2.00
#
#       alcohol
# mean    10.44
# std      1.08
# min      8.40
# 25%      9.50
# 50%     10.20
# 75%     11.10
# max     14.90
# --------------------------------------------------------------------------------------------------------------------------------------------
# After Oversampling
# Shape X_Res:  (2898, 12)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# mean           8.45              0.58         0.29            2.61       0.09
# std            1.70              0.24         0.21            1.20       0.05
# min            4.60              0.12         0.00            0.90       0.01
# 25%            7.20              0.39         0.08            1.93       0.07
# 50%            8.10              0.54         0.29            2.20       0.08
# 75%            9.50              0.71         0.46            2.76       0.09
# max           15.90              1.58         1.00           15.50       0.61
#
#       free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# mean                13.33                 37.32     1.00 3.31       0.67
# std                  9.16                 28.01     0.00 0.16       0.18
# min                  1.00                  6.00     0.99 2.74       0.33
# 25%                  6.00                 17.41     1.00 3.21       0.56
# 50%                 10.73                 29.00     1.00 3.31       0.63
# 75%                 17.32                 47.89     1.00 3.41       0.74
# max                 68.00                289.00     1.00 4.01       2.00
#
#       alcohol
# mean    10.64
# std      1.19
# min      8.40
# 25%      9.69
# 50%     10.49
# 75%     11.50
# max     14.90

# %%
# add both columns and return this data as op
X_res['quality'] = y_res

# %%
X_res
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.40              0.70         0.00            1.90       0.08
# 1              7.80              0.88         0.00            2.60       0.10
# 2              7.80              0.76         0.04            2.30       0.09
# 3             11.20              0.28         0.56            1.90       0.07
# 4              7.40              0.70         0.00            1.90       0.08
# ...             ...               ...          ...             ...        ...
# 2893          10.70              0.35         0.53            2.60       0.07
# 2894           9.58              0.30         0.54            3.52       0.08
# 2895           7.69              0.39         0.34            1.93       0.06
# 2896          11.02              0.49         0.60            3.98       0.08
# 2897           7.73              0.36         0.35            1.74       0.06
#
#       free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                   11.00                 34.00     1.00 3.51       0.56
# 1                   25.00                 67.00     1.00 3.20       0.68
# 2                   15.00                 54.00     1.00 3.26       0.65
# 3                   17.00                 60.00     1.00 3.16       0.58
# 4                   11.00                 34.00     1.00 3.51       0.56
# ...                   ...                   ...      ...  ...        ...
# 2893                 5.00                 16.00     1.00 3.15       0.65
# 2894                 5.80                 16.20     1.00 3.17       0.90
# 2895                11.86                 23.06     0.99 3.27       0.74
# 2896                 5.53                 17.60     1.00 3.19       0.67
# 2897                 4.13                 12.62     1.00 3.28       0.95
#
#       alcohol    Id  quality
# 0        9.40     0        5
# 1        9.80     1        5
# 2        9.80     2        5
# 3        9.80     3        6
# 4        9.40     4        5
# ...       ...   ...      ...
# 2893    11.00   496        8
# 2894    11.88   440        8
# 2895    11.44  1362        8
# 2896    12.28   475        8
# 2897    10.64  1327        8
#
# [2898 rows x 13 columns]

# %%
X['quality'] = y

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.40              0.70         0.00            1.90       0.08
# 1              7.80              0.88         0.00            2.60       0.10
# 2              7.80              0.76         0.04            2.30       0.09
# 3             11.20              0.28         0.56            1.90       0.07
# 4              7.40              0.70         0.00            1.90       0.08
# ...             ...               ...          ...             ...        ...
# 1138           6.30              0.51         0.13            2.30       0.08
# 1139           6.80              0.62         0.08            1.90       0.07
# 1140           6.20              0.60         0.08            2.00       0.09
# 1141           5.90              0.55         0.10            2.20       0.06
# 1142           5.90              0.65         0.12            2.00       0.07
#
#       free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                   11.00                 34.00     1.00 3.51       0.56
# 1                   25.00                 67.00     1.00 3.20       0.68
# 2                   15.00                 54.00     1.00 3.26       0.65
# 3                   17.00                 60.00     1.00 3.16       0.58
# 4                   11.00                 34.00     1.00 3.51       0.56
# ...                   ...                   ...      ...  ...        ...
# 1138                29.00                 40.00     1.00 3.42       0.75
# 1139                28.00                 38.00     1.00 3.42       0.82
# 1140                32.00                 44.00     0.99 3.45       0.58
# 1141                39.00                 51.00     1.00 3.52       0.76
# 1142                32.00                 44.00     1.00 3.57       0.71
#
#       alcohol    Id  quality
# 0        9.40     0        5
# 1        9.80     1        5
# 2        9.80     2        5
# 3        9.80     3        6
# 4        9.40     4        5
# ...       ...   ...      ...
# 1138    11.00  1592        6
# 1139     9.50  1593        6
# 1140    10.50  1594        5
# 1141    11.20  1595        6
# 1142    10.20  1597        5
#
# [1143 rows x 13 columns]

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
for i in df.columns :
     print(f"{i.replace(' ', '_')} : float")
# Out:
# fixed_acidity : float
# volatile_acidity : float
# citric_acid : float
# residual_sugar : float
# chlorides : float
# free_sulfur_dioxide : float
# total_sulfur_dioxide : float
# density : float
# pH : float
# sulphates : float
# alcohol : float
# quality : float
# Id : float

# %%
# insights on range of data we may expect as input
df.describe().iloc[[3,7], :-2]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# min            4.6              0.12          0.0             0.9      0.012
# max           15.9              1.58          1.0            15.5      0.611
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# min                  1.0                   6.0  0.99007  2.74       0.33
# max                 68.0                 289.0  1.00369  4.01       2.00
#
#      alcohol
# min      8.4
# max     14.9

# %%
df.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0

# %%
x = dict()

col = df.columns
row = df.head(1)

for i in zip(col, row) :
     print(i[0], ' - ', i[1])
# Out:
# fixed acidity  -  fixed acidity
# volatile acidity  -  volatile acidity
# citric acid  -  citric acid
# residual sugar  -  residual sugar
# chlorides  -  chlorides
# free sulfur dioxide  -  free sulfur dioxide
# total sulfur dioxide  -  total sulfur dioxide
# density  -  density
# pH  -  pH
# sulphates  -  sulphates
# alcohol  -  alcohol
# quality  -  quality
# Id  -  Id

# %%
x = dict(df.iloc[1, :])
